# %%
##basic syntex rules in python
## python is a case sensitive
name="john"
Name="mark"
print(name)
print(Name)
# Out:
# john
# mark

# %% [markdown]
#  Indentation
# python is used to define the stucture and hierarchy of the code.unlike many programming languages that use braces{} to delimit block of code, python indentation to detemine the grouping of statements.
# this means that all the statements within a block must be indented at the same level

# %%
## indentation 
## python uses indentation to define block of code. consistent use of apaces (commonly 4) or a tab is required
age=30
if age>28:
    print(age)


print(age)
# Out:
# 30
# 30

# %%
## this is a single line comment
print("hello world ")
# Out:
# hello world

# %%
## line continuation
## use a backslash (\) to continue a statement to the next line

total = 1+2+3+4+5+6+7+\
4+5+6
print(total)
# Out:
# 43

# %%
## multiple statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##understand semnatics in python
# variable assignment
age = 32 ## age is an integer
name = "john" ##name is a string

# %%
## type interence 
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable = 10
print(type(variable))
variable="john"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 30
if age>28:
    print(age)
# Out:
# 30

# %%
##code example of indentation
if True:
    print("correct indentation")
if False:
    print("this ont print")
print("this will print")
print("outside the if block ")
# Out:
# correct indentation
# this will print
# outside the if block
