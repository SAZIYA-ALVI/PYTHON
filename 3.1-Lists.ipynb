# %% [markdown]
# LIST

# %%
lst =[]
print(type(lst))
# Out:
# <class 'list'>

# %%
name = ["j","h","t","i","1"]
print(name)
# Out:
# ['j', 'h', 't', 'i', '1']

# %%
mixed_lst = [1 , "hello", 3.14, True]
print(mixed_lst)
# Out:
# [1, 'hello', 3.14, True]

# %%
## accessing list Elements
fruits = ["banana", "mango","apple", "fig","orange"]
print(fruits)
print(fruits[2])
print(fruits[0])
print(fruits[4])
print(fruits[-2])
# Out:
# ['banana', 'mango', 'apple', 'fig', 'orange']
# apple
# banana
# orange
# fig

# %%
print(fruits[1:])
print(fruits[2:3])
print(fruits[1:3])
print(fruits[-1:-3])
print(fruits[-4:-2])
# Out:
# ['mango', 'apple', 'fig', 'orange']
# ['apple']
# ['mango', 'apple']
# []
# ['mango', 'apple']

# %% [markdown]
# Modifying the list element

# %%
fruits[1] = "kiwi" 
print(fruits)
# Out:
# ['banana', 'kiwi', 'apple', 'fig', 'orange']

# %%
fruits[1:] = "kiwi"

# %%
fruits
# Out:
# ['banana', 'k', 'i', 'w', 'i']

# %%
fruits = ["banana", "mango","apple", "banana","fig","orange"]

# %% [markdown]
# List Method

# %%
fruits.append("guava")
print(fruits)
# Out:
# ['banana', 'mango', 'apple', 'banana', 'fig', 'orange', 'guava']

# %%
fruits.insert(1,"watermelon")
print(fruits)
# Out:
# ['banana', 'watermelon', 'watermelon', 'mango', 'apple', 'banana', 'fig', 'orange', 'guava']

# %% [markdown]
# Remove the item

# %%
fruits.remove("banana")
print(fruits)
# Out:
# ['watermelon', 'mango', 'apple', 'banana', 'fig', 'orange', 'guava']

# %%
## Remove and return the last
#fruits.pop()
popped_fruits = fruits.pop()
print(popped_fruits)
print(fruits)
# Out:
# apple
# ['watermelon', 'mango']

# %%
index = fruits.index("mango")
print(index)
# Out:
# 1

# %%
fruits = ["banana", "mango","apple", "fig","orange"]

# %%
fruits.insert(2, "apple")
print(fruits.count("apple"))
# Out:
# 3

# %%
fruits
# Out:
# ['banana', 'mango', 'apple', 'apple', 'apple', 'fig', 'orange']

# %%
fruits.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
fruits.reverse() ## reverse the list

# %%
fruits
# Out:
# ['banana', 'mango', 'apple', 'apple', 'apple', 'fig', 'orange']

# %%
print(fruits)
# Out:
# ['banana', 'mango', 'apple', 'apple', 'apple', 'fig', 'orange']

# %%
fruits.clear() ## remove all item from the list
print(fruits)
# Out:
# []

# %% [markdown]
# Sclicing list

# %%
number = [1,2,3,4,5,6,7]
print(number[2:5])
print(number[:3])
print(number[5:])
print(number[:2])
print(number[:: -2])
# Out:
# [3, 4, 5]
# [1, 2, 3]
# [6, 7]
# [1, 2]
# [7, 5, 3, 1]

# %%
number[::3]
# Out:
# [1, 4, 7]

# %%
number[:: -2]
# Out:
# [7, 5, 3, 1]

# %%
## Iterating over list
for number in numbers:
    print(number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 ## Iterating over list
# ----> 2 for number in numbers:
#       3     print(numbers)
#
# NameError: name 'numbers' is not defined

# %%
## iterting with index
for index,number in enumerate(numbers):
    print(index, number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 ## iterting with index
# ----> 2 for index,number in enumerate(numbers):
#       3     print(index, number)
#
# NameError: name 'numbers' is not defined

# %%
## list compehension
lst = []
for x in range(10):
    lst.append(x**2)
    print(lst)
# Out:
# [0]
# [0, 1]
# [0, 1, 4]
# [0, 1, 4, 9]
# [0, 1, 4, 9, 16]
# [0, 1, 4, 9, 16, 25]
# [0, 1, 4, 9, 16, 25, 36]
# [0, 1, 4, 9, 16, 25, 36, 49]
# [0, 1, 4, 9, 16, 25, 36, 49, 64]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[x**2 for x in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ## list comprehension
# Bsic syntex [ expression for item in iterable]
# with conditional logic [ expression for item in iterable if condition]

# %%
square = [num**2 for num in range(10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
## list comprehension with condition
for i in range(10):
    if i%2 == 0:
        lst.append(i)
    print(lst)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4, 6]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4, 6]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4, 6, 8]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4, 6, 8]

# %%
even_numbers = [num for num in range(10) if num%2 == 0]
print(even_numbers)
# Out:
# [0, 2, 4, 6, 8]

# %%
## nested list comphresion
lst1 = [1,2,3,4]
lst2 = ['a', 'b', 'c','d']
pair = [[i,j] for i in lst1 for j in lst2]
print(pair)
# Out:
# [[1, 'a'], [1, 'b'], [1, 'c'], [1, 'd'], [2, 'a'], [2, 'b'], [2, 'c'], [2, 'd'], [3, 'a'], [3, 'b'], [3, 'c'], [3, 'd'], [4, 'a'], [4, 'b'], [4, 'c'], [4, 'd']]

# %%
## list comprehension with function call 
words = ["hello ", "world", "python", "list"]
lenghts = [len(word) for word in words]
print(lenghts) # output:[5,5,6,4,13]
# Out:
# [6, 5, 6, 4]
