# %% [markdown]
# Exception  are event that disrupt the normal flow of a problem. they occure when an error is encountederd during program execution. common exeception include

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
## exception try, except block 
try:
    a = b
except:
    print("The variable has not assigned")
# Out:
# The variable has not assigned

# %%
try:
    a = b
except NameError as ex:
    print("ex")
# Out:
# ex

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the demoninator greater than 0")
# Out:
# division by zero
# Please enter the demoninator greater than 0

# %%
try:
    result = 1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the demoninator greater than 0")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 try:
#       2     result = 1/2
# ----> 3     a=b
#       4 except ZeroDivisionError as ex:
#       5     print(ex)
#
# NameError: name 'b' is not defined

# %%
try:
    result = 1/2
    a =b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the demoninator greater than 0")
except  Exception as ex1:## main parent derive exception
    print(ex1)
    print("Main exception got caught here")
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num = int(input("Enter a number "))
    result = 10/num
except ValueError :
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater then 0")
# Out:
# Enter denominator greater then 0

# %%
try:
    num = int(input("Enter a number "))
    result = 10/num
except ValueError :
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater then 0")
except Exception as ex:
     print(ex)

# %%
## try , except , else block
try:
    num = int(input("Enter a number:"))
    result = 10/num
except ValueError:
    print("That is not valid number")
except ZeroDivisionError:
    print("You can't divide by zero! ")
except Exception as ex:
    print(ex)
else:
    print(f" the result is {result}")
# Out:
#  the result is -1.6666666666666667

# %%
## try , execpt , else and finally 
try:
    num = int(input("Entet a number :"))
    result = 10/num
except ValueError:
    print("tHAT IS NOT A VALID NUMBER! ")
except ZeroDivisionError:
    print("You can not divide by zero! ")
except  Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("Execution complete. ")
# Out:
# The result is 0.8333333333333334
# Execution complete.

# %% [markdown]
# File handling & Exception handling

# %%
try:
  file = open('example.txt','r')
  content = file.read()
  a = b
  print(content)
except FileNotFoundError:
  print("The file does not exists")
except Exception as ex:
  print(ex)
finally:
  if 'file' in locals() and not file.closed():
    file.close()
    print("file close")
# Out:
# The file does not exists
