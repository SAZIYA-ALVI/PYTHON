# %%
## Integer example
age = 30
type(age)
# Out:
# int

# %%
## floting type data type
height = 5.7
print(height)
print(type(height))
# Out:
# 5.7
# <class 'float'>

# %%
## string datatype example
name = "john"
print(name)
print(type(name))
# Out:
# john
# <class 'str'>

# %%
## boolean datatype
is_true = True
type(is_true)
# Out:
# bool

# %%
a = 10
b =10
type(a==b)
##bool()
# Out:
# bool

# %%
## common errors
result = "hello"+"5"

# %%
result = "hello"+str(5)
print(result)
# Out:
# hello5
