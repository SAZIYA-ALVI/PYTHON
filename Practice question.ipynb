# %% [markdown]
# How to remove duplicates from a list?

# %%
#Method 1:
Number = [1,2,3,4,5,5,2,2,1,1,1,1]
result = list(set(Number))
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Method 2 (preserve order):
Number = [1,2,3,4,5,5,2,2,1,1,1,1]
result = []
for i in Number:
    if i not in result:
        result.append(i)
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# *ARGS
#
# Used for multiple positional arguments.

# %%
def total(*args):
   return sum(args)
    
print(total(1,2,3,4,5))
# Out:
# 15

# %% [markdown]
# **Kwargs
#
# Used for multiple keyword arguments.

# %%
def Student(**kwargs):
     print(kwargs)
Student(name = "Ali", Age = "22")
# Out:
# {'name': 'Ali', 'Age': '22'}

# %% [markdown]
#  Reverse a string

# %%
S = "python"
reverse = S[ ::-1]
print(reverse)
# Out:
# nohtyp

# %% [markdown]
# Check palindrome string

# %%
s = "madam"
if s[ :: -1]:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Palindrome

# %% [markdown]
# Find maximum number in list

# %%
number = [12,32,45,22,20,21]
maximum = number[0]
for i in number:
    if i>maximum:
        maximum = i 
print(maximum)
# Out:
# 45

# %% [markdown]
#  Count frequency of elements

# %%
numbers=[1,2,2,3,3,3]
freq = {}

for i in number:
    freq[i] = freq.get(i,0)+1
print(freq)
# Out:
# {12: 1, 32: 1, 45: 1, 22: 1, 20: 1, 21: 1}
